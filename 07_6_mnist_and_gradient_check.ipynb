# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# # 7-6. Applying for MNIST and Gradient check

# %%
log = pickle.load(open('./code/05/log.pkl', 'rb'))

# %%
log
# Out:
# {'accuracy_test': [0.095799999999999996,
#   0.1135,
#   0.28739999999999999,
#   0.47920000000000001,
#   0.61729999999999996,
#   0.71540000000000004,
#   0.76739999999999997,
#   0.79800000000000004,
#   0.82289999999999996,
#   0.8367,
#   0.84960000000000002,
#   0.85919999999999996,
#   0.86960000000000004,
#   0.87609999999999999,
#   0.88270000000000004,
#   0.88629999999999998,
#   0.89339999999999997,
#   0.89580000000000004,
#   0.89859999999999995,
#   0.90039999999999998,
#   0.90239999999999998,
#   0.90400000000000003,
#   0.90510000000000002,
#   0.90469999999999995,
#   0.90710000000000002,
#   0.9083,
#   0.90890000000000004,
#   0.91180000000000005,
#   0.9123,
#   0.91320000000000001],
#  'accuracy_test_itr': [0,
#   100,
#   200,
#   300,
#   400,
#   500,
#   600,
#   700,
#   800,
#   900,
#   1000,
#   1100,
#   1200,
#   1300,
#   1400,
#   1500,
#   1600,
#   1700,
#   1800,
#   1900,
#   2000,
#   2100,
#   2200,
#   2300,
#   2400,
#   2500,
#   2600,
#   2700,
#   2800,
#   2900],
#  'accuracy_train': [0.089999999999999997,
#   0.14999999999999999,
#   0.26000000000000001,
#   0.53000000000000003,
#   0.68999999999999995,
#   0.68000000000000005,
#   0.83999999999999997,
#   0.76000000000000001,
#   0.84999999999999998,
#   0.84999999999999998,
#   0.84999999999999998,
#   0.90000000000000002,
#   0.85999999999999999,
#   0.82999999999999996,
#   0.88,
#   0.84999999999999998,
#   0.90000000000000002,
#   0.91000000000000003,
#   0.88,
#   0.95999999999999996,
#   0.90000000000000002,
#   0.95999999999999996,
#   0.90000000000000002,
#   0.94999999999999996,
#   0.93999999999999995,
#   0.93000000000000005,
#   0.90000000000000002,
#   0.93999999999999995,
#   0.84999999999999998,
#   0.92000000000000004],
#  'accuracy_train_itr': [0,
#   100,
#   200,
#   300,
#   400,
#   500,
#   600,
#   700,
#   800,
#   900,
#   1000,
#   1100,
#   1200,
#   1300,
#   1400,
#   1500,
#   1600,
#   1700,
#   1800,
#   1900,
#   2000,
#   2100,
#   2200,
#   2300,
#   2400,
#   2500,
#   2600,
#   2700,
#   2800,
#   2900],
#  'loss_test': [2.3035139823917183,
#   2.2949680811296926,
#   2.2191457008050683,
#   1.8869504340326864,
#   1.449724356469221,
#   1.1430413154188217,
#   0.9457813751861246,
#   0.81115122988560973,
#   0.71071376410079579,
#   0.64034733054654325,
#   0.58436810503437053,
#   0.54195319031244182,
#   0.50507572456966021,
#   0.478408178435617,
#   0.45423465561072096,
#   0.43484723020382826,
#   0.4152352193063466,
#   0.40051681610503298,
#   0.38753778470825273,
#   0.37662864049653738,
#   0.36457290203751269,
#   0.35677159636353695,
#   0.3503415731766264,
#   0.34330727473627698,
#   0.33711457557191155,
#   0.32973871905350355,
#   0.32451631049620366,
#   0.31899878072854942,
#   0.31503991632185885,
#   0.31106994400624977],
#  'loss_test_itr': [0,
#   100,
#   200,
#   300,
#   400,
#   500,
#   600,
#   700,
#   800,
#   900,
#   1000,
#   1100,
#   1200,
#   1300,
#   1400,
#   1500,
#   1600,
#   1700,
#   1800,
#   1900,
#   2000,
#   2100,
#   2200,
#   2300,
#   2400,
#   2500,
#   2600,
#   2700,
#   2800,
#   2900],
#  'loss_train': [2.3015427612253494,
#   2.2886129661166983,
#   2.233423218834012,
#   1.8794041322645192,
#   1.4320161860935456,
#   1.1890651168418258,
#   0.90194601034894162,
#   0.8273942063983688,
#   0.79649542587496358,
#   0.57789471116919811,
#   0.63986728696140172,
#   0.48282101540520322,
#   0.51838009102442495,
#   0.54629184793354202,
#   0.46331295498362463,
#   0.54307200988383209,
#   0.4695156580188411,
#   0.32886222345707367,
#   0.40706898409532999,
#   0.23066490135626971,
#   0.34104095952716856,
#   0.23049004063101289,
#   0.42587890247143539,
#   0.23364411349834749,
#   0.27866059002387261,
#   0.2713697601601805,
#   0.32368109299003722,
#   0.28202310923878654,
#   0.39626091770838173,
#   0.30095081971922466],
#  'loss_train_itr': [0,
#   100,
#   200,
#   300,
#   400,
#   500,
#   600,
#   700,
#   800,
#   900,
#   1000,
#   1100,
#   1200,
#   1300,
#   1400,
#   1500,
#   1600,
#   1700,
#   1800,
#   1900,
#   2000,
#   2100,
#   2200,
#   2300,
#   2400,
#   2500,
#   2600,
#   2700,
#   2800,
#   2900]}

# %%
plt.plot(log['loss_train_itr'], log['loss_train'], label='loss_train')
plt.plot(log['loss_test_itr'], log['loss_test'], label='loss_test')
plt.legend()
plt.show()

# %%
plt.plot(log['accuracy_train_itr'], log['accuracy_train'], label='accuracy_train')
plt.plot(log['accuracy_test_itr'], log['accuracy_test'], label='accuracy_test')
plt.legend()
plt.show()

# %% [markdown]
# ## Gradient Checking
#
# [Coursera](https://www.coursera.org/learn/deep-neural-network/lecture/htA0l/gradient-checking)
#
# $$
# difference = \frac{\lVert grad - numericalgrad \rVert_2}{\lVert grad \rVert_2 + \lVert numericalgrad \rVert_2}
# $$
#
# Threshold: $10^{-7}$
