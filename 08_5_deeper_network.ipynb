# %%
import numpy as np
# %matplotlib inline
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# # 8-5. Deeper Network

# %% [markdown]
# ## Basic Two Layer Net

# %%
two_layer_log = pickle.load(open('code/08_techniques/08_5_deeper_net/basic_two_layer_log.pkl', "rb"))
print(two_layer_log["accuracy_test"][-1])
# Out:
# 0.9189

# %%
plt.plot(two_layer_log['loss_train_itr'], two_layer_log['loss_train'], 'r')
plt.plot(two_layer_log['loss_test_itr'], two_layer_log['loss_test'], 'b')
plt.show()

# %% [markdown]
# ## Naive Seven Layer Net

# %%
naive_seven_layer_log = pickle.load(open('code/08_techniques/08_5_deeper_net/naive_seven_layer_log.pkl', "rb"))
print(naive_seven_layer_log["accuracy_test"][-1])
# Out:
# 0.1135

# %%
plt.plot(naive_seven_layer_log['loss_train_itr'], naive_seven_layer_log['loss_train'], 'r')
plt.plot(naive_seven_layer_log['loss_test_itr'], naive_seven_layer_log['loss_test'], 'b')
plt.show()

# %% [markdown]
# ## Seven Layer Net
#
# Using
# * ReLU activation function
# * He initialization

# %%
seven_layer_log = pickle.load(open('code/08_techniques/08_5_deeper_net/seven_layer_log.pkl', "rb"))
print(seven_layer_log["accuracy_test"][-1])
# Out:
# 0.9659

# %%
plt.plot(seven_layer_log['loss_train_itr'], seven_layer_log['loss_train'], 'r')
plt.plot(seven_layer_log['loss_test_itr'], seven_layer_log['loss_test'], 'b')
plt.show()

# %% [markdown]
# ## Better Seven Layer Net
#
# Using
# * Adam Optimizer
# * 10 epochs

# %%
better_seven_layer_log = pickle.load(open('code/08_techniques/08_5_deeper_net/better_seven_layer_log.pkl', "rb"))
print(better_seven_layer_log["accuracy_test"])
# Out:
# [0.094399999999999998, 0.86580000000000001, 0.90680000000000005, 0.92430000000000001, 0.93189999999999995, 0.93700000000000006, 0.94199999999999995, 0.94469999999999998, 0.94550000000000001, 0.95409999999999995, 0.95199999999999996, 0.95540000000000003, 0.95699999999999996, 0.9577, 0.95999999999999996, 0.96050000000000002, 0.95430000000000004, 0.96220000000000006, 0.95550000000000002, 0.96419999999999995, 0.96099999999999997, 0.96289999999999998, 0.96599999999999997, 0.96109999999999995, 0.96040000000000003, 0.96430000000000005, 0.96289999999999998, 0.96289999999999998, 0.96630000000000005, 0.96750000000000003, 0.96479999999999999, 0.96819999999999995, 0.9647, 0.96819999999999995, 0.96089999999999998, 0.96299999999999997, 0.96340000000000003, 0.96660000000000001, 0.96560000000000001, 0.96779999999999999, 0.96689999999999998, 0.97209999999999996, 0.96779999999999999, 0.96419999999999995, 0.96799999999999997, 0.96970000000000001, 0.97140000000000004, 0.97109999999999996, 0.97199999999999998, 0.96750000000000003, 0.96279999999999999, 0.97009999999999996, 0.97040000000000004, 0.96660000000000001, 0.97419999999999995, 0.97199999999999998, 0.9708, 0.97270000000000001, 0.96789999999999998, 0.97119999999999995]

# %%
plt.plot(better_seven_layer_log['loss_train_itr'], better_seven_layer_log['loss_train'], 'r')
plt.plot(better_seven_layer_log['loss_test_itr'], better_seven_layer_log['loss_test'], 'b')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Overfitting
#
# Using
# * More neurons
# * More layers
# * 20 epochs

# %%
overfitting = pickle.load(open('code/08_techniques/08_5_deeper_net/overfitting_log.pkl', "rb"))
print(overfitting["accuracy_test"][-1])
# Out:
# 0.9826

# %%
plt.plot(overfitting['loss_train_itr'], overfitting['loss_train'], 'r')
plt.plot(overfitting['loss_test_itr'], overfitting['loss_test'], 'b')
plt.yscale('log')
plt.show()
